# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import numpy as np

import keras
import tensorflow as tf 
from keras.layers import Conv2D, Dense
from keras.layers import concatenate, add
from keras.layers import BatchNormalization, Activation, PReLU
from keras.layers import Input, Flatten, UpSampling2D
from keras.models import Model
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping
import keras.backend as K
from keras.applications.vgg19 import VGG19

from shutil import rmtree

from batch_generator import COCOBatchGenerator
from bsd100_callback import BSD100_Evaluator
from utils import print_available_devices, deprocess_HR, deprocess_LR

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
if tf.test.is_built_with_cuda():
    data_format = 'channels_first'
    keras.backend.set_image_data_format('channels_first')
else:
    data_format = 'channels_last'
    keras.backend.set_image_data_format('channels_last')

# %%
print("Keras : ", keras.__version__)
print("\t data_format : ", keras.backend.image_data_format())
print("Tensorflow : ", tf.__version__)
print_available_devices()
# Out:
# Keras :  2.1.6
# 	 data_format :  channels_first
# Tensorflow :  1.8.0
# Device : /device:CPU:0
# 	 type : CPU
# 	 desc :
#
# Device : /device:GPU:0
# 	 type : GPU
# 	 desc :device: 0, name: GeForce GTX 1070, pci bus id: 0000:02:00.0, compute capability: 6.1

# %% [markdown]
# ## Parameters

# %%
B = 16 # number of residual block

batch_size = 16
target_size = (96,96)
downscale_factor = 4

num_steps = 1e5
steps_per_epoch = 5000
epochs = int(num_steps//steps_per_epoch)

# axis used in Parametric ReLU !
shared_axis = [1,2] if data_format == 'channels_last' else [2,3]

# axis for Batch Normalization
axis = -1 if data_format == 'channels_last' else 1

print('epochs = ', epochs)
# Out:
# epochs =  20

# %% [markdown]
# ## Build the Generator

# %%
# build a residual block
def res_block(inputs):
    x = Conv2D(64, kernel_size=(3,3), strides=(1,1), padding='same', activation=None, use_bias=False)(inputs)
    x = BatchNormalization(axis=axis)(x)
    x = PReLU(alpha_initializer='zeros', alpha_regularizer=None, alpha_constraint=None, shared_axes=shared_axis)(x)
    x = Conv2D(64, kernel_size=(3,3), strides=(1,1), padding='same', activation=None, use_bias=False)(x)
    x = BatchNormalization(axis=axis)(x)
    return add([x, inputs])

# build an upscale block
# PixelShuffler is replaced by an UpSampling2D layer (nearest upsampling)

def up_block(x):
    x = Conv2D(256, kernel_size=(3,3), strides=(1,1) , padding='same', activation=None, use_bias=False)(x)
    x = UpSampling2D(size=(2, 2))(x)
    x = PReLU(alpha_initializer='zeros', alpha_regularizer=None, alpha_constraint=None, shared_axes=shared_axis)(x)
    return x

# %%
input_generator = Input(shape=(None, None, 3) if data_format=='channels_last' else (3, None, None), 
                        name='input_generator')

x = Conv2D(filters=64, kernel_size=(9,9),
           strides=(1,1), padding='same',
           activation=None)(input_generator)

x_input_res_block = PReLU(alpha_initializer='zeros',
                          alpha_regularizer=None,
                          alpha_constraint=None,
                          shared_axes=shared_axis)(x)

x = x_input_res_block

# add B residual blocks 
for i in range(B):
    x = res_block(x)

x = Conv2D(64, kernel_size=(3,3), strides=(1,1), padding='same', activation=None, use_bias=False)(x)
x = BatchNormalization(axis=axis)(x)

# skip connection
x = add([x, x_input_res_block])

# two upscale blocks
x = up_block(x)
x = up_block(x)

# final conv layer : activated with tanh -> pixels in [-1, 1]
output_generator = Conv2D(3, kernel_size=(9,9), 
                          strides=(1,1), activation='tanh',
                          use_bias=False, padding='same')(x)

generator = Model(inputs=input_generator, outputs=output_generator)

# %%
generator.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_generator (InputLayer)    (None, 3, None, None 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, None, Non 15616       input_generator[0][0]
# __________________________________________________________________________________________________
# p_re_lu_1 (PReLU)               (None, 64, None, Non 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, None, Non 36864       p_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, None, Non 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# p_re_lu_2 (PReLU)               (None, 64, None, Non 64          batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, None, Non 36864       p_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, None, Non 256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, None, Non 0           batch_normalization_2[0][0]
#                                                                  p_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, None, Non 36864       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, None, Non 256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# p_re_lu_3 (PReLU)               (None, 64, None, Non 64          batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, None, Non 36864       p_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, None, Non 256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, None, Non 0           batch_normalization_4[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, None, Non 36864       add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, None, Non 256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# p_re_lu_4 (PReLU)               (None, 64, None, Non 64          batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, None, Non 36864       p_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, None, Non 256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 64, None, Non 0           batch_normalization_6[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, None, Non 36864       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 64, None, Non 256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# p_re_lu_5 (PReLU)               (None, 64, None, Non 64          batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 64, None, Non 36864       p_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64, None, Non 256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 64, None, Non 0           batch_normalization_8[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 64, None, Non 36864       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 64, None, Non 256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# p_re_lu_6 (PReLU)               (None, 64, None, Non 64          batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 64, None, Non 36864       p_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 64, None, Non 256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 64, None, Non 0           batch_normalization_10[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, None, Non 36864       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 64, None, Non 256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# p_re_lu_7 (PReLU)               (None, 64, None, Non 64          batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, None, Non 36864       p_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 64, None, Non 256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 64, None, Non 0           batch_normalization_12[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, None, Non 36864       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, None, Non 256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# p_re_lu_8 (PReLU)               (None, 64, None, Non 64          batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, None, Non 36864       p_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64, None, Non 256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 64, None, Non 0           batch_normalization_14[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, None, Non 36864       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, None, Non 256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# p_re_lu_9 (PReLU)               (None, 64, None, Non 64          batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, None, Non 36864       p_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 64, None, Non 256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 64, None, Non 0           batch_normalization_16[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, None, Non 36864       add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 64, None, Non 256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# p_re_lu_10 (PReLU)              (None, 64, None, Non 64          batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 64, None, Non 36864       p_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 64, None, Non 256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 64, None, Non 0           batch_normalization_18[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, None, Non 36864       add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 64, None, Non 256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# p_re_lu_11 (PReLU)              (None, 64, None, Non 64          batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 64, None, Non 36864       p_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 64, None, Non 256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 64, None, Non 0           batch_normalization_20[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 64, None, Non 36864       add_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 64, None, Non 256         conv2d_22[0][0]
# __________________________________________________________________________________________________
# p_re_lu_12 (PReLU)              (None, 64, None, Non 64          batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 64, None, Non 36864       p_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 64, None, Non 256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 64, None, Non 0           batch_normalization_22[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 64, None, Non 36864       add_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 64, None, Non 256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# p_re_lu_13 (PReLU)              (None, 64, None, Non 64          batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 64, None, Non 36864       p_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 64, None, Non 256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 64, None, Non 0           batch_normalization_24[0][0]
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 64, None, Non 36864       add_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 64, None, Non 256         conv2d_26[0][0]
# __________________________________________________________________________________________________
# p_re_lu_14 (PReLU)              (None, 64, None, Non 64          batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 64, None, Non 36864       p_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 64, None, Non 256         conv2d_27[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 64, None, Non 0           batch_normalization_26[0][0]
#                                                                  add_12[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 64, None, Non 36864       add_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 64, None, Non 256         conv2d_28[0][0]
# __________________________________________________________________________________________________
# p_re_lu_15 (PReLU)              (None, 64, None, Non 64          batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 64, None, Non 36864       p_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 64, None, Non 256         conv2d_29[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 64, None, Non 0           batch_normalization_28[0][0]
#                                                                  add_13[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 64, None, Non 36864       add_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 64, None, Non 256         conv2d_30[0][0]
# __________________________________________________________________________________________________
# p_re_lu_16 (PReLU)              (None, 64, None, Non 64          batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 64, None, Non 36864       p_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 64, None, Non 256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 64, None, Non 0           batch_normalization_30[0][0]
#                                                                  add_14[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 64, None, Non 36864       add_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 64, None, Non 256         conv2d_32[0][0]
# __________________________________________________________________________________________________
# p_re_lu_17 (PReLU)              (None, 64, None, Non 64          batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 64, None, Non 36864       p_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 64, None, Non 256         conv2d_33[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 64, None, Non 0           batch_normalization_32[0][0]
#                                                                  add_15[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 64, None, Non 36864       add_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 64, None, Non 256         conv2d_34[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 64, None, Non 0           batch_normalization_33[0][0]
#                                                                  p_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 256, None, No 147456      add_17[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 256, None, No 0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# p_re_lu_18 (PReLU)              (None, 256, None, No 256         up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 256, None, No 589824      p_re_lu_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 256, None, No 0           conv2d_36[0][0]
# __________________________________________________________________________________________________
# p_re_lu_19 (PReLU)              (None, 256, None, No 256         up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 3, None, None 62208       p_re_lu_19[0][0]
# ==================================================================================================
# Total params: 2,041,664
# Trainable params: 2,037,440
# Non-trainable params: 4,224
# __________________________________________________________________________________________________

# %% [markdown]
# ### Add VGG19 as Perceptual Loss

# %%
def preproces_vgg(x):
    # scale from [-1,1] to [0, 255]
    x += 1.
    x *= 127.5
    
    # RGB -> BGR
    if data_format == 'channels_last':
        x = x[..., ::-1]
    else:
        x = x[:,::-1,:,:]
    
    # apply Imagenet preprocessing : BGR mean
    mean = [103.939, 116.778, 123.68]
    _IMAGENET_MEAN = K.constant(-np.array(mean))
    x = K.bias_add(x, K.cast(_IMAGENET_MEAN, K.dtype(x)))
    
    return x

# %%
def vgg_loss(y_true, y_pred):
    # load pretrained VGG
    vgg19 = VGG19(include_top=False,
                  input_shape=target_size+(3,) if data_format=='channels_last' else (3,)+target_size, 
                  weights='imagenet')
    vgg19.trainable = False
    for l in vgg19.layers:
        l.trainable = False
    
    # create a model that ouputs the features from level 'block2_conv2'
    features_extractor = Model(inputs=vgg19.input, outputs=vgg19.get_layer("block2_conv2").output)
    
    # compute the features, y_pred and y_true are tensors scaled in [-1, 1]
    # it needs te be rescaled and shifted to respect VGG preprocessing strategy
    features_pred = features_extractor(preproces_vgg(y_pred))
    features_true = features_extractor(preproces_vgg(y_true))
    
    # adding the scaling factor (to have similar values as with MSE within image space)
    return 0.006*K.mean(K.square(features_pred - features_true), axis=-1)

# %%
opt = Adam(lr=1e-4, beta_1=0.9)
generator.compile(loss=vgg_loss, optimizer=opt)
# Out:
# /root/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/keras/applications/vgg19.py:191: UserWarning: You are using the TensorFlow backend, yet you are using the Theano image data format convention (`image_data_format="channels_first"`). For best performance, set `image_data_format="channels_last"` in your Keras config at ~/.keras/keras.json.
#   warnings.warn('You are using the TensorFlow backend, yet you '

# %% [markdown]
# ## Training data

# %%
batch_gen = COCOBatchGenerator(directory='data/COCO/train2014/',
                               batch_size=batch_size,
                               downscale_factor=4,
                               target_size=target_size,
                               shuffle=True,
                               crop_mode='fixed_size',
                               color_mode='rgb',
                               data_format=data_format)
# Out:
# Found 0 images

# %%
batch_LR, batch_HR = batch_gen.next()
print(batch_LR.shape)
print(batch_HR.shape)

if data_format == 'channels_first':
    batch_LR = np.transpose(batch_LR, (0,2,3,1))
    batch_HR = np.transpose(batch_HR, (0,2,3,1))

# LR| HR 
fig, axes = plt.subplots(4, 2, figsize=(7, 15))
for i in range(4):
    axes[i, 0].imshow(deprocess_LR(batch_LR[i]).astype(np.uint8))
    axes[i, 1].imshow(deprocess_HR(batch_HR[i]).astype(np.uint8))

# %% [markdown]
# ## Train 'generator' with MSE Loss

# %%
if os.path.isdir('checkpoints/SRResNet-VGG22/'):
    rmtree('checkpoints/SRResNet-VGG22/')
os.mkdir('checkpoints/SRResNet-VGG22/')

# %%
checkpoint = ModelCheckpoint(filepath='checkpoints/SRResNet-VGG22/weights.{epoch:02d}-{loss:.2f}.hdf5',
                             monitor='loss',
                             save_weights_only=True,
                             period=10,
                             verbose=2)

best_checkpoint = ModelCheckpoint(filepath='checkpoints/SRResNet-VGG22/best_weights.hdf5',
                                  monitor='loss',
                                  save_weights_only=True,
                                  save_best_only=True, 
                                  period=1,
                                  verbose=2)

bsd100_callback = BSD100_Evaluator(directory='data/BSD100/',
                                   filepath='checkpoints/SRResNet-VGG22/BSD100/',
                                   downscale_factor=4,
                                   color_mode='rgb',
                                   verbose=1,
                                   data_format=data_format,
                                   margin=5)


early_stop = EarlyStopping(monitor='loss',min_delta=0, patience=3, verbose=1, mode='min')


callbacks = [checkpoint, best_checkpoint, bsd100_callback, early_stop]

# %%
# %%time
history = generator.fit_generator(batch_gen,
                                  epochs=epochs,
                                  callbacks=callbacks,
                                  steps_per_epoch=steps_per_epoch)

# %%
plt.figure(figsize=(16, 4))
plt.plot(history.history['loss'])
plt.title('training loss')
plt.ylabel('mse [-1, 1]')
plt.xlabel('epoch')
plt.show()

plt.figure(figsize=(16, 4))
plt.plot(bsd100_callback.logs['mse'])
plt.title('validation loss')
plt.ylabel('mse [0, 255]')
plt.xlabel('epoch')
plt.show()

# %%
plt.figure(figsize=(16, 4))
plt.plot(bsd100_callback.logs['psnr'])
plt.title('validation PSNR')
plt.ylabel('PSNR (dB)')
plt.xlabel('epoch')
plt.show()
